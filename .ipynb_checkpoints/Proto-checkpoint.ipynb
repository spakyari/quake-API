# %%
import sqlalchemy
import pandas as pd

from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect, distinct, and_, inspect

import datetime as dt

# %%
engine = create_engine("sqlite:///Earthquake.db")
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['quakes']

# %%
conn = engine.connect()
quakes_pd = pd.read_sql("SELECT * FROM quakes", conn)
# Out:
#         e_id                      date_time   latitude   longitude   depth  \
# 0          0  1975-12-31 14:34:22.080000000  36.813500 -121.132333   5.881
# 1          1  1975-12-31 02:53:56.256000000  34.279000 -116.337000   2.330
# 2          2  1975-12-30 23:37:52.896000000  36.905667 -121.637167  -0.155
# 3          3  1975-12-30 23:04:47.424000000  36.838667 -121.569833   4.774
# 4          4  1975-12-30 18:10:28.128000000  35.781000 -121.421000  11.895
# ...      ...                            ...        ...         ...     ...
# 80382  80382  2016-01-03 09:12:46.368000000  41.848300 -119.601600   6.700
# 80383  80383  2016-01-03 04:34:59.808000000  41.869000 -119.613700   9.900
# 80384  80384  2016-01-02 06:38:32.928000000  38.085667 -121.916000  20.430
# 80385  80385  2016-01-01 20:02:39.552000000  40.175500 -122.228833  32.750
# 80386  80386  2016-01-01 13:40:30.720000000  39.268333 -123.229667   6.070
#
#         mag magType   nst     gap     dmin  ...                   updated  \
# 0      2.71      md  50.0   97.00  0.06757  ...  2016-12-15T05:09:40.840Z
# 1      2.70      md   0.0   71.00     None  ...  2016-01-29T21:39:32.720Z
# 2      2.67      md  13.0  137.00  0.03243  ...  2016-12-15T05:08:54.636Z
# 3      2.67      md  46.0   81.00  0.01892  ...  2016-12-15T05:08:50.998Z
# 4      3.15      md  17.0  247.00   0.2396  ...  2016-12-15T05:08:39.866Z
# ...     ...     ...   ...     ...      ...  ...                       ...
# 80382  2.50      ml   8.0   75.42    0.179  ...  2018-07-02T17:44:50.027Z
# 80383  2.50      ml   8.0   99.14    0.159  ...  2018-07-02T17:44:48.976Z
# 80384  2.50      md  68.0   83.00   0.0982  ...  2017-02-09T18:12:19.290Z
# 80385  2.56      md  20.0  124.00  0.08559  ...  2017-02-09T18:04:27.831Z
# 80386  2.58      md  39.0   77.00  0.08378  ...  2017-02-09T18:03:11.400Z
#
#                                      place          type horizontalError  \
# 0                       Central California    earthquake            0.23
# 1                16km N of Joshua Tree, CA    earthquake            None
# 2                       Central California  quarry blast            0.34
# 3                       Central California    earthquake            0.21
# 4              offshore Central California    earthquake            1.04
# ...                                    ...           ...             ...
# 80382         72km ESE of Lakeview, Oregon    earthquake            None
# 80383         70km ESE of Lakeview, Oregon    earthquake            None
# 80384     6km NNW of Pittsburg, California    earthquake            0.26
# 80385     0km ESE of Red Bluff, California    earthquake            0.83
# 80386  2km W of Redwood Valley, California    earthquake            0.13
#
#       depthError             magError magNst    status locationSource  \
# 0          0.640                 0.09   15.0  reviewed             nc
# 1          0.847                 None    0.0  reviewed             ci
# 2          1.060                 0.77    3.0  reviewed             nc
# 3          0.360                 0.28   11.0  reviewed             nc
# 4          0.610                 0.55    4.0  reviewed             nc
# ...          ...                  ...    ...       ...            ...
# 80382      7.200                 0.34    5.0  reviewed             nn
# 80383      4.200                 0.21    5.0  reviewed             nn
# 80384      0.190                0.155   71.0  reviewed             nc
# 80385      1.370                0.154   47.0  reviewed             nc
# 80386      0.460  0.27699999999999997   40.0  reviewed             nc
#
#        magSource
# 0             nc
# 1             ci
# 2             nc
# 3             nc
# 4             nc
# ...          ...
# 80382         nn
# 80383         nn
# 80384         nc
# 80385         nc
# 80386         nc
#
# [80387 rows x 23 columns]

# %%
lon = -120
lat = 36
radius = 30
start_date = '2016-01-01'
end_date = '2017-05-05'

cols = 'date_time, latitude, longitude, depth, mag'
sql = f"SELECT * FROM quakes where {start_date} < date_time and date_time < {end_date}"
quakes_pd = pd.read_sql(sql, conn)

quakes_pd
# Out:
# Empty DataFrame
# Columns: [e_id, date_time, latitude, longitude, depth, mag, magType, nst, gap, dmin, rms, net, id, updated, place, type, horizontalError, depthError, magError, magNst, status, locationSource, magSource]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# ## Retrieve last 30 days function

# %%
StartDate = 1
EndDate = 2

def GetCountries():
url = f'https://earthquake.usgs.gov/fdsnws/event/1/query.geojson?starttime={StartDate}&endtime={EndDate}&maxlatitude=41.961&minlatitude=32.813&maxlongitude=-114.521&minlongitude=-124.255&minmagnitude=2.5&orderby=time'

# %%
dt.Today()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-e726f6ddef0b> in <module>
# ----> 1 dt.Today()
#
# AttributeError: module 'datetime' has no attribute 'Today'
